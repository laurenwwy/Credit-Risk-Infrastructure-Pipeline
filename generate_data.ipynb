# %%
'''
Generating the Data
write a script to create a "Synthetic Dataset" that looks like real loan data.
'''
# Out:
# '\nGenerating the Data\nwrite a script to create a "Synthetic Dataset" that looks like real loan data.\n'

# %%
import pandas as pd
import numpy as np
import os

# Create a 'data' folder to keep things organized
# os let you interact with the operating system
if not os.path.exists('data'):
    os.makedirs('data')

def generate_bank_data(records=5000):
    np.random.seed(42) # Ensures the "random" data is the same every time you run it
    
    data = {
        'loan_id': range(1000, 1000 + records),
        'customer_income': np.random.randint(30000, 150000, records),
        'credit_score': np.random.randint(300, 850, records),
        'loan_amount': np.random.randint(5000, 50000, records),
        # np.random.uniform is used to generate random float numbers within a specified range
        'interest_rate': np.random.uniform(0.03, 0.25, records),
        # np.random.choice is used to randomly select values from a given list with specified probabilities
        'employment_status': np.random.choice(['Employed', 'Self-Employed', 'Unemployed'], records, p=[0.8, 0.15, 0.05]),
        'current_balance': np.random.randint(1000, 50000, records)
    }
    
    df = pd.DataFrame(data)
    print(df)
    # Save as a CSV file (The "Raw" data)
    df.to_csv('data/raw_loans.csv', index=False)
    print("✅ Successfully generated 5,000 loan records in data/raw_loans.csv")

if __name__ == "__main__":
    generate_bank_data()
# Out:
#       loan_id  customer_income  credit_score  loan_amount  interest_rate  \
# 0        1000            45795           791        31548       0.233350
# 1        1001            30860           498        40434       0.186727
# 2        1002           133694           661        30039       0.111042
# 3        1003           149879           740        37530       0.186866
# 4        1004           140268           325        43736       0.038861
# ...       ...              ...           ...          ...            ...
# 4995     5995            79429           690        11106       0.208173
# 4996     5996           112152           425        12333       0.158583
# 4997     5997           138048           793        36913       0.115924
# 4998     5998            68458           346        36283       0.054112
# 4999     5999            76169           775        44423       0.226998
#
#      employment_status  current_balance
# 0             Employed            34447
# 1        Self-Employed            18131
# 2             Employed            28429
# 3             Employed            18705
# 4        Self-Employed            49710
# ...                ...              ...
# 4995          Employed            35392
# 4996          Employed            16968
# 4997          Employed            12149
# 4998          Employed            10717
# 4999          Employed            17642
#
# [5000 rows x 7 columns]
# ✅ Successfully generated 5,000 loan records in data/raw_loans.csv
